# %% [markdown]
# <a href="https://colab.research.google.com/github/weepingwillow2001/data_analysis_practice/blob/main/7%EC%9E%A5/7_3_0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from pandas import Series, DataFrame

# Series 생성 예제
s = pd.Series([1, 2, 3, None])

s
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# dtype: float64

# %%
s.dtype
# Out:
# dtype('float64')

# %%
# "정수형" 데이터 타입 사용
s = pd.Series([1, 2, 3, None], dtype=pd.Int64Dtype())

s
# Out:
# 0       1
# 1       2
# 2       3
# 3    <NA>
# dtype: Int64

# %%
# "문자열"로 데이터 타입 지정
q = pd.Series([1, 2, 3, None], dtype="Int64")

q
# Out:
# 0       1
# 1       2
# 2       3
# 3    <NA>
# dtype: Int64

# %%
s.isna()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# dtype: bool

# %%
s.dtype
# Out:
# Int64Dtype()

# %%
s[3]

# %%
s[3] is pd.NA
# Out:
# True

# %%
# 문자열 데이터 타입
s = pd.Series(['one', 'two', None, 'three'], dtype=pd.StringDtype())

s
# Out:
# 0      one
# 1      two
# 2     <NA>
# 3    three
# dtype: string

# %%
# 여러 타입이 섞인 DataFrame 생성
df = pd.DataFrame({"A": [1, 2, None, 4],
                  "B": ["one", "two", "three", None],
                  "C": [False, None, False, True]})

df
# Out:
#      A      B      C
# 0  1.0    one  False
# 1  2.0    two   None
# 2  NaN  three  False
# 3  4.0   None   True

# %%
# 열별로 데이터 타입 "변환": astype
df["A"] = df["A"].astype("Int64")
df["B"] = df["B"].astype("string")
df["C"] = df["C"].astype("boolean")

df
# Out:
#       A      B      C
# 0     1    one  False
# 1     2    two   <NA>
# 2  <NA>  three  False
# 3     4   <NA>   True
